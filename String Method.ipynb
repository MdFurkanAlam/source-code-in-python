# %% [markdown]
# # strip() methode

# %%
a="         time is precious  "
b=a.strip()
print(b)
print(a)
# Out:
# time is precious
#          time is precious

# %% [markdown]
# # Lower() method

# %%
a="How Are you Doing ?"
b=a.lower()
print(b)
print(a)
# Out:
# how are you doing ?
# How Are you Doing ?

# %%
a="HeLLo Hope yOu aRe weLL"
b= "wHaTs Your PLAN For Sunday"
print(a.lower()+" "+b.lower())
# Out:
# hello hope you are well whats your plan for sunday

# %% [markdown]
# # upper() method

# %%
p=" pracTICS MaKes MaN PerFect"
print(p.upper())
# Out:
#  PRACTICS MAKES MAN PERFECT

# %%
p=" pracTICS MaKes MaN PerFect"
q="so lets practice soMe queStions of PythOn"
print(p.upper()+" "+q.upper())
# Out:
#  PRACTICS MAKES MAN PERFECT SO LETS PRACTICE SOME QUESTIONS OF PYTHON

# %%
x="      Honesty is the best Policy      "
y="          HONEST MAN is ALWAYS GOOD"
z="we APPREciate HOnesty      "
m=x.strip()
n=y.strip()
o=z.strip()
print(m.lower()+" "+n.lower()+" "+o.lower())
# Out:
# honesty is the best policy honest man is always good we appreciate honesty

# %% [markdown]
# # replace() method

# %%
a="hello how are you?"
print(a.replace("hello","hey"))
# Out:
# hey how are you?

# %%
a=""" maths- 28 out of 30
science- 27 out of 30
social - 23 out of 30
science - 25 out of 30
english- 21 out of 30 """
print(a.replace("out of","/"))
# Out:
#  maths- 28 / 30
# science- 27 / 30
# social - 23 / 30
# science - 25 / 30
# english- 21 / 30

# %%
#Example of a revers string
def fun():
    a = "hello"
    a = list(a)
    first = 0
    last = len(a) - 1
    
    while first < last:
        temp = a[first]
        a[first] = a[last]
        a[last] = temp
        first += 1
        last -= 1
    reversed_str = "".join(a) 
    print(reversed_str)

fun()
# Out:
# olleh

# %% [markdown]
# # Split() method

# %%
a="this is - the class of - python basics - to advanced"
b=a.split("-")
print(b)
print(type(a))
print(type(b))
# Out:
# ['this is ', ' the class of ', ' python basics ', ' to advanced']
# <class 'str'>
# <class 'list'>

# %%
a="red,blue,green,pink,are the colours off the ball"
b=a.split(",")
print(b)
# Out:
# ['red', 'blue', 'green', 'pink', 'are the colours off the ball']

# %%
print(b[0])
print(b[3])
# Out:
# red
# pink

# %%
a="red % blue % green % pink % are the colours off the ball"
b=a.split("%")
print(b)
# Out:
# ['red ', ' blue ', ' green ', ' pink ', ' are the colours off the ball']

# %% [markdown]
# # Capitalize() Method

# %%
a="earth revolves around the sun"
print(a.capitalize())
# Out:
# Earth revolves around the sun

# %%
a="earth revolves around the sun"
b="moon is so beautiful"
print(a.capitalize() + " "+ b.capitalize())
# Out:
# Earth revolves around the sun Moon is so beautiful

# %% [markdown]
# # title() method

# %%
a="india is a beautiful country"
print(a.title())
# Out:
# India Is A Beautiful Country

# %%
 b="earth RevolveS arOnD The sUn"
print(b.title())
# Out:
# Earth Revolves Arond The Sun

# %%
b="earth RevolveS aronD The sUn"
c=b.replace("The","a")
print(c)
print(c.title())
# Out:
# earth RevolveS aronD a sUn
# Earth Revolves Arond A Sun

# %% [markdown]
# # swapcase() methode

# %%
a="new delhi is the capital of india"
print(a.swapcase())
# Out:
# NEW DELHI IS THE CAPITAL OF INDIA

# %%
b="DELHI IS A BEAUTIFUL CITY"
print(b.swapcase())
# Out:
# delhi is a beautiful city

# %%
a="new delhi is the capital of india"
b="DELHI IS A BEAUTIFUL CITY"
print(a.swapcase()+" "+b.swapcase())
# Out:
# NEW DELHI IS THE CAPITAL OF INDIA delhi is a beautiful city

# %%
s="earth RevolveS aronD The sUn"
print(s.swapcase())
# Out:
# EARTH rEVOLVEs ARONd tHE SuN

# %% [markdown]
# # find() methode

# %%
a="python is great"
b=a.find("g")
print(len(a))
print(b)
# Out:
# 15
# 10

# %%
a="python is great"
b=a.find("thon")
print(len(a))
print(b)
# Out:
# 15
# 2

# %%
a="python is great"
b=a.find("world")
print(len(a))
print(b)
# Out:
# 15
# -1

# %% [markdown]
# # index() methode

# %%
a=[10,0,30,40,50,"python"]
p=a.index("python")
print(p)
# Out:
# 5

# %%
b=['apple','banana','orange','mangoes','grapes']
c=b.index('orange')
print(c)
# Out:
# 2

# %% [markdown]
# # isalnum() method

# %%
a="python"
print(a.isalnum())
# Out:
# True

# %%
a="stdennt@" #only alphabet and numeric value
print(a.isalnum())
# Out:
# False

# %%
a="python  " # no space ,only alphabet and numeric value
print(a.isalnum())
# Out:
# False

# %%
a="student8983hhdb"
print(a.isalnum())
# Out:
# True

# %%
a="student,12"#no unother value
print(a.isalnum())
# Out:
# False

# %% [markdown]
# # isalpha() method

# %%
a="teacher"
print(a.isalpha())
# Out:
# True

# %%
a="TEAcher"
print(a.isalpha())
# Out:
# True

# %%
a="TEACHER"
print(a.isalpha())
# Out:
# True

# %%
a="teacher13"
print(a.isalpha())
# Out:
# False

# %%
a="python is so easy to learn do you agree"# Because space is
print(a.isalpha())
# Out:
# False

# %%
a="jkcdh83kjd" # Because number is
print(a.isalpha())
# Out:
# False

# %%
a="Md.Furkan.Alam"  # Because unother value is
print(a.isalpha())
# Out:
# False

# %% [markdown]
# # isdigit() method

# %%
a="7461968015" #all characters in the string are digits.
print(a.isdigit())
# Out:
# True

# %%
a="Furkan7461" #the string contains 1 or more non digit.
print(a.isdigit())
# Out:
# False

# %%
a="74619 68015" # No space
print(a.isdigit())
# Out:
# False

# %%
""" write a moblie number and take this as an input from the user and chheck moblie number is valid or not"""
a=input("Enter your Moblie number")
if a.isdigit()==True:
    print("Moblie number is valid")
else:
    print("Moblie nnumber is not valid")
# Out:
# Enter your Moblie number 9798807867
# Moblie number is valid

# %%
""" write a moblie number and take this as an input from the user and chheck moblie number is valid or not"""
a=input("Enter your Moblie number")
if a.isdigit()==True:
    print("Moblie number is valid")
else:
    print("Moblie nnumber is not valid")
# Out:
# Enter your Moblie number 979880ali
# Moblie nnumber is not valid

# %% [markdown]
# # isupper() method

# %%
str="WELCOME TO THE MY HOME"
print(str.isupper())
# Out:
# True

# %%
str="welcome to the my home"
print(str.isupper())
# Out:
# False

# %%
str="WELcome To The My Home"
print(str.isupper())
# Out:
# False

# %%
a="MY NUMBER IS 7461968015"# it's method is accept numeric value
print(a.isupper())
# Out:
# True

# %% [markdown]
# # islower() method

# %%
p="how are you ?"
print(p.islower())
# Out:
# True

# %%
p="How Are You"
print(p.islower())
# Out:
# False

# %%
p="how are you 8938932<"
print(p.islower())
# Out:
# True

# %% [markdown]
# # istitle() method

# %%
p="Python Is Easy"
print(p.istitle())
# Out:
# True

# %%
p="python is easy"
print(p.istitle())
# Out:
# False

# %%
p="Python is Easy"
print(p.istitle())
# Out:
# False

# %%
p="Python Is Easy 12345"
print(p.istitle())
# Out:
# True

# %%
p="PYTHO IS EASY 12345"
print(p.istitle())
# Out:
# False

# %% [markdown]
# # startswith() method

# %%
a="python is easy"
print(a.startswith("python"))
# Out:
# True

# %%
a="Python is easy" #Because P letter is small serch
print(a.startswith("python"))
# Out:
# False

# %%
A="hello how are you"
print(A.startswith("hey"))
# Out:
# False

# %%
A="hello how are you"
print(A.startswith("hello"))
# Out:
# True

# %% [markdown]
# # endswith() method

# %%
A="hello how are you"
print(A.endswith("you"))
# Out:
# True

# %%
a="what a wonderful day"# d!=D
print(A.endswith("Day"))
# Out:
# False

# %% [markdown]
# # How to check a particular substring is part of a string or not

# %%
a="I am learnig pyhon"
print("learnig" in a)
# Out:
# True

# %%
a="I am learnig pyhon"
print("learnig" not in a)
# Out:
# False

# %%
a="I am learnig pyhon"
print("hello" in a)
# Out:
# False

# %%
a="I am learnig pyhon"
print("hello" not in a)
# Out:
# True
