# %% [markdown]
# # how many variables are in the notebook

# %%
x=6
y=5.344
z=12+2j
o="Hello student ,23 student are present in the class"

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# o          str        Hello student ,23 student<...> are present in the class
# x          int        6
# y          float      5.344
# z          complex    (12+2j)

# %%
del z # delete z variable

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# o          str      Hello student ,23 student<...> are present in the class
# x          int      6
# y          float    5.344

# %%
a=12
b=13
c=14
print(a)
print(b)
print(c)
# Out:
# 12
# 13
# 14

# %% [markdown]
# # multiple assignments

# %% [markdown]
#  # Python Arithmetic Operators

# %% [markdown]
# # Add operatos

# %%
a=2
b=4
c=3.5
d=" Hello Student "
e=" how are you"
f=6+8j

# %%
print(a+b)
# Out:
# 6

# %%
print(a+c)
# Out:
# 5.5

# %%
print(a+f)
# Out:
# (8+8j)

# %%
print(c+f)
# Out:
# (9.5+8j)

# %% [markdown]
# # Subtract opetors

# %%
print(b-a)
# Out:
# 2

# %%
print(b-c)
# Out:
# 0.5

# %%
print(a-b)
# Out:
# -2

# %%
print(f-a)
# Out:
# (4+8j)

# %%
print(f-c)
# Out:
# (2.5+8j)

# %%
print(d-e)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 print(d-e)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# # multiplication

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         Hello Student
# e          str         how are you
# f          complex    (6+8j)
# o          str        Hello student ,23 student<...> are present in the class
# x          int        6
# y          float      5.344

# %%
print(a*b)
# Out:
# 8

# %%
print(a*c)
# Out:
# 7.0

# %%
print(a*f)
# Out:
# (12+16j)

# %%
print(c*f)
# Out:
# (21+28j)

# %%
print(d*e)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print(d*e)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# # divison operator

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         Hello Student
# e          str         how are you
# f          complex    (6+8j)
# o          str        Hello student ,23 student<...> are present in the class
# x          int        6
# y          float      5.344

# %%
print(b/a)
# Out:
# 2.0

# %%
print(b/c)
# Out:
# 1.1428571428571428

# %%
print(f/a)
# Out:
# (3+4j)

# %%
print(f/c)
# Out:
# (1.7142857142857142+2.2857142857142856j)

# %%
print(d/e)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print(d/e)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# # modulus operator

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         Hello Student
# e          str         how are you
# f          complex    (6+8j)
# o          str        Hello student ,23 student<...> are present in the class
# x          int        6
# y          float      5.344

# %%
print(b%a)
# Out:
# 0

# %%
print(c%a)
# Out:
# 1.5

# %%
print(f%a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 print(f%a)
#
# TypeError: unsupported operand type(s) for %: 'complex' and 'int'

# %% [markdown]
# # Exponent opertor

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         Hello Student
# e          str         how are you
# f          complex    (6+8j)
# o          str        Hello student ,23 student<...> are present in the class
# x          int        6
# y          float      5.344

# %%
print(a**4)
# Out:
# 16

# %%
print(a**b)
# Out:
# 16

# %%
print(c**18)
# Out:
# 6211904899.255558

# %%
print(c**b)
# Out:
# 150.0625

# %%
print(f**2)
# Out:
# (-28+96j)

# %%
 print((23**9)-(65*98) + (89+547)+ (8478*834)-(32822-3232))
# Out:
# 1801159696791

# %% [markdown]
# # floor divion

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        2
# b          int        4
# c          float      3.5
# d          str         Hello Student
# e          str         how are you
# f          complex    (6+8j)

# %%
print(b//a)
# Out:
# 2

# %%
print(c//a)
# Out:
# 1.0

# %%
add= a+b
print(add)
# Out:
# 6

# %%
@and=123
# Out:
#   Cell In[19], line 1
#     @and=123
#      ^
# SyntaxError: invalid syntax

# %%
_a=6

# %%
print(_a)
# Out:
# 6

# %%
_b=123
print(_b)
# Out:
# 123

# %% [markdown]
# # Python Assignment operator

# %%
m=15

# %%
m+=10
print(m)
# Out:
# 25

# %%
n=14

# %%
n-=10
print(n)
# Out:
# 4

# %%
m=15
m*=10
print(m)
# Out:
# 150

# %%
m=15
m/=10
print(m)
# Out:
# 1.5

# %%
m=15
m**=2
print(m)
# Out:
# 225

# %%
m=15
m%=10
print(m)
# Out:
# 5

# %%
m=15
m//=10
print(m)
# Out:
# 1

# %% [markdown]
# # python logical & Boolean operator

# %%
a= True 
b=True
c=False
d=False

# %%
type(a)
# Out:
# bool

# %%
type(c)
# Out:
# bool

# %%
print(a and b)
# Out:
# True

# %%
print(b and c)
# Out:
# False

# %%
print(c and a)
# Out:
# False

# %%
print(c and d)
# Out:
# False

# %%
print((a and b) and (c and d))
# Out:
# False

# %%
a=True 
b=True
c=False
d=False

# %%
print( a or b)
# Out:
# True

# %%
print(b or c)
# Out:
# True

# %%
print(c or a)
# Out:
# True

# %%
print(c or d)
# Out:
# False

# %%
print((a or b) or (c or d) or (d or a))
# Out:
# True

# %%
print((a and b) or (a or c) and (d and c))
# Out:
# True

# %%
a=True 
b=True
c=False
d=False

# %%
print(not a)
# Out:
# False

# %%
print(not c)
# Out:
# True

# %%
print(not((a and b)or(a or c)and(b and c)or(d or a)))
# Out:
# False

# %%
print(not((a and c ) or (b and d)and (a and b)))
# Out:
# True

# %% [markdown]
# # Comparison operators

# %%
c=2<3
print(c)
# Out:
# True

# %%
type(c)
# Out:
# bool

# %%
d=2==3
print(d)
# Out:
# False

# %%
3==3.0
# Out:
# True

# %%
p=12
q=8
r=-3
s=5.56

# %%
print((q<p)and(r>s))
# Out:
# False

# %%
print(q<p)
# Out:
# True

# %%
print(not((p==q)or(r==s)))
# Out:
# True

# %%
print((p>=r)and(r<=s)or(q<=r))
# Out:
# True

# %%
True or False and True
# Out:
# True

# %%
print((not(2!=3) and True )or (False and True))
# Out:
# False

# %%
20 & 20
# Out:
# 20

# %% [markdown]
# # Bitwise operator

# %%
a=5
b=4
print(a&b) #And(&) operator
# Out:
# 4

# %%
print(type(a&b))#And(&) operator
# Out:
# <class 'int'>

# %%
a=347440
b=83837
print(a&b) #And(&) operator
# Out:
# 83248

# %%
a=6
b=8
print(a|b) #OR(|) operator
# Out:
# 14

# %%
a=5
b=4
print(a^b) #XOR(^) operator
# Out:
# 1

# %%
a=6
b=10
print(a^b)  #XOR(^) operator
# Out:
# 12

# %%
a=5
print(~a) # Bitwise Not(~)
# Out:
# -6

# %%
a=8
print(~a)# Bitwise Not(~)
# Out:
# -9

# %%
a=8343747
print(~a)# Bitwise Not(~)
# Out:
# -8343748

# %%
a=5
print(a<<2) # Bitwise left shift(<<)
# Out:
# 20

# %%
a=5
print(a<<3) # Bitwise left shift(<<)
# Out:
# 40

# %%
a=7
print(a<<2) # Bitwise left shift(<<)
# Out:
# 28

# %%
a=5
print(a>>2) # Bitwise Right shift(>>)
# Out:
# 1

# %%
a=7
print(a>>3) # Bitwise Right shift(>>)
# Out:
# 0

# %%
a=9
print(a>>2) # Bitwise Right shift(>>)
# Out:
# 2
