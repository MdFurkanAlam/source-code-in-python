# %% [markdown]
# # UNIT 4

# %% [markdown]
# # if Condition

# %%
""" take two number from the user and  print the greater one  """
a=int(input("Enter the 1st value"))
b=int(input("Enter the 2nd value"))
if a>b:
    print("The greater value is a",a)
if b>a:
    print("The greater value is b",b)

# %%
""" enter the value from the user, and check the number is true or false """
value=bool(int(input("Enter Value: ")))
if value==True:
    print("Value is True")
if value==False:
    print("Value is False")
# Out:
# Enter Value:  0
# Value is False

# %%
""" umpaire tossed a con, if it will be head team A will bat first if it will be Tail then team B will bat first """
a=str(input("Tossed a coin"))
if a=="head":
    print("Team A will bat first")
if a=="tail":
    print("Team B will bat first")
# Out:
# Tossed a coin head
# Team A will bat first

# %%
""" enter a number from the user , and check the number is divisible by 13 or not """
a=int(input("Enter the number"))
if a%13==0:
    print("The number is divisible by 13")
if a%13!=0:
    print("The number is not divisible by 13")
# Out:
# Enter the number 74
# The number is not divisible by 13

# %%
""" raju for shopping if he purches blue ball than, he will play from the side of blue team, if raju will purchase green ball then he will play from the side of green team  """
z=input("Enter the colour of ball")
if z=="blue":
    print("Raju will  play in blue team")
if z=="green":
    print("Raju will play in green team")
# Out:
# Enter the colour of ball green
# Raju will play in green team

# %% [markdown]
# # if else condition

# %%
""" take a value from the usre, and if the will be greater than 20 print magic and if the value is not greater than 20 print no magic """
a=int(input("Enter the value "))
if a>20:
    print("Magic")
else:
    print("No Magic")
# Out:
# Enter the value  12
# No Magic

# %%
"""enter the age of the user, if age greater than 60 print senior citizen, age is than less than 60, print not a senior citizen"""
a=int(input("Enter the age"))
if a>60:
    print("Senior Citizen")
else:
    print("Not a Senior Citizen")
# Out:
# Enter the age 23
# Not a Senior Citizen

# %%
""" Ask the user to enter his age , if the age will be more than 18 year than eligible for voting """
a=int(input("Enter the your age"))
if a>=18:
    print("Eligible for vote")
else:
    print("Not Eligible for vote")
# Out:
# Enter the your age 12
# Not Eligible for vote

# %% [markdown]
# # if elif else statement

# %%
""" Enter two value from the user and if thhe vlue will be greater print greater if the value is not greater print no greater and if the vlue is equal print equal"""
a=int(input("enter the 1st value "))
b=int(input("enter the 2nd value "))
if a>b:
    print("The value is greate")
elif a<b:
    print("The value is not  greate")
else:
    print("The value is equal")
# Out:
# enter the 1st value  90
# enter the 2nd value  390
# The value is not  greate

# %%
""" take a vlue from the user and check it is divisible by 2 or 3 or neither 2 or 3 """
x=int(input("Enter the value"))
if x%2==0:
    print("The value is divisible by 2")
elif x%3==0:
    print("The value is divisible by 3")
else :
    print("The value is not  divisible by 2 and 3")
# Out:
# Enter the value 5
# The value is not  divisible by 2 and 3

# %%
""" Enter the marks of the student , if greater than or equal to 85 print A Grad, marks is greater than or equal to 80 print B grad and so on E grad """
marks=int(input("Enter the Marks"))
if marks>=85:
    print("A Grad")
elif marks>=80 and marks<85:
    print("B Grad")
elif marks>=75 and marks<80:
    print("C Grad")
elif marks>=70 and marks<75:
    print("D Grad")
elif marks>=65 and marks<70:
    print("E Grad")
else:
    print("Fail")
# Out:
# Enter the Marks 95
# A Grad

# %%
""" write a program and take the number from user in between 1 to 7 if number will be 1 print monday if number will be 2 print tuesday and so on"""
w=int(input("Enter the number"))
if w==1:
    print("Monday")
elif w==2:
    print("Tuesday")
elif w==3:
    print("Wednesday")
elif w==4:
    print("Thursday")
elif w==5:
    print("Friday")
elif w==6:
    print("Saturday")
elif w==7:
    print("Sunday")
else:
    print("No Days")
# Out:
# Enter the number 5
# Friday

# %% [markdown]
# # Nested if statement

# %%
""" enter the value  from user, and check is it greater than 10 or 20 not"""
v=int(input("Enter the vlaue"))
if v>10:
    print("Inside the if condition")
    if v>20:
        print("Inside the nested if")
    else:
        print("Inside the else part of nested if")
else:
    print("outside the condition")
# Out:
# Enter the vlaue 12
# Inside the if condition
# Inside the else part of nested if

# %%
""" enter user, number of class attended by student, number of assignment submitted by student , if attendance will be greater than 75 then only Student can appear in exam one, if student attendance is greater than 75 and submitted more 10 assignment than only appear in Exam two"""
a=int(input("Enter the number of classes attended by student"))
b=int(input("Enter the number of assignment submitted by student"))
if a>75:
    print("Eligible for exam one")
    if b>10:
        print("Eligible for exam one and two")
    else:
        print("Eligible for exam one but not eligible for exam two")
else:
    print("you are suspended")
# Out:
# Enter the number of classes attended by student 74
# Enter the number of assignment submitted by student 89
# you are suspended

# %%
 """ Wrrite a program to check a student pass or fail as per every subject"""
m=int(input(" Enter the math marks"))
e=int(input(" Enter the english marks"))
h=int(input(" Enter the hindi marks"))
s=int(input(" Enter the science marks"))
c=int(input(" Enter the computer marks"))

marks = [h, e, m, s, c]

if all(mark >= 33 for mark in marks):
    print("pass")
else:
    print("fail")

# %%
if m>=33:
    if 
    pass
if e>=33:
    pass
if h>=33:
    pass
if s>=33:
    pass
if c>=33:
    pass
marks=m+e+h+s+c
print("Total Marks",marks)
if marks>=300:
    print("1st Division")
elif marks>=225 and marks<300:
    print("2nd")
elif marks>=165 and marks<225:
    print("3rd")
else:
    print("Faill")
# Out:
# Total Marks 415
# 1st Division
